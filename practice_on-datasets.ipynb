# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
churn = pd.read_csv('churn.csv')

# %%
churn.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge   ...    Eve Calls  \
# 0             25     265.1        110       45.07   ...           99
# 1             26     161.6        123       27.47   ...          103
# 2              0     243.4        114       41.38   ...          110
# 3              0     299.4         71       50.90   ...           88
# 4              0     166.7        113       28.34   ...          122
#
#    Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
iris = pd.read_csv('iris_new.csv')

# %%
iris.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %%
irs = sns.load_dataset('iris')

# %%
irs.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.barplot(x = 'sepal_length', y = 'species', data = irs)

# %%
migration = pd.read_csv('migration.csv')

# %%
migration.head()
# Out:
#   source destination  migrants  distance   pops66   pops71    popd66  popd71
# 0    PEI        NFLD       255       924   108535   111641  493396.0  522104
# 1     NS        NFLD      2380       952   756039   788960  493396.0  522104
# 2     NB        NFLD      1140      1119   616788   534557       NaN  522104
# 3    QUE        NFLD      2145      1641  5780845  6027764  493396.0  522104
# 4    ONT        NFLD      6295      1996  6960870  7703106  493396.0  522104

# %%
mtcars = pd.read_csv('mtcars.csv')

# %%
mtcars.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
#
#           am  gear  carb
# 0     Manual     4     4
# 1     Manual     4     4
# 2     Manual     4     1
# 3  Automatic     3     1
# 4  Automatic     3     2

# %%
sns.barplot(x = 'sepal_length', y = 'species', data = irs, estimator = np.std)

# %%
sns.countplot(x='species', data=irs)

# %%
sns.countplot(x='sepal_length', data=irs)

# %%
sns.boxplot(x='sepal_length', y='species', data=irs, palette='rainbow')

# %%
sns.boxplot(data=irs, palette='rainbow', orient='h')

# %%
sns.boxplot(data=irs, palette="coolwarm")

# %%
sns.violinplot(data=irs, palette="coolwarm")

# %%
sns.violinplot(x='sepal_length', hue='species', data=irs, palette="rainbow")

# %%
sns.stripplot(data=irs, jitter=True, palette='Set1')

# %%
sns.swarmplot(data=irs, palette='Set1')

# %%
sns.violinplot(data=irs, palette="coolwarm")
sns.swarmplot(data=irs, palette='Set1')

# %%
sns.factorplot(x='species',y='sepal_length',data=irs,kind='bar')
sns.factorplot(x='species',y='sepal_width',data=irs,kind='bar')
